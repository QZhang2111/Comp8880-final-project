# %%
import networkx as nx

import matplotlib.pyplot as plt
import random
import json
import community as community_louvain
import numpy as np
import numpy as np
from scipy.sparse import csr_matrix

# 设置随机种子
random.seed(42)
np.random.seed(42)
from networkx.algorithms.community import girvan_newman

# %%
def read_directed_graph(file_path, skip_lines):
    G = nx.DiGraph()  # Initialize an empty directed graph
    with open(file_path, 'r') as file:
        for _ in range(skip_lines):
            next(file)  # Skip the initial descriptive lines
        for line in file:
            parts = line.strip().split()
            if len(parts) == 2:  # Only consider lines with exactly two node identifiers
                u, v = parts
                G.add_edge(u, v)
    
    return G


path = '/Users/qing/Desktop/24s1/comp8880/project/code/data/soc/soc-Slashdot0811.txt'
G = read_directed_graph(path,3)
G.remove_edges_from(nx.selfloop_edges(G))

# %%
local[:3]

# %%
num_nodes = G.number_of_nodes()
num_edges = G.number_of_edges()

num_nodes, num_edges
# Out:
# (77360, 828161)

# %%
with open('saved/network_metrics_slash.json', 'r') as f:
    loaded_data = json.load(f)

# 访问加载的数据
sorted_centrality = loaded_data["Centrality"]
sorted_pagerank =  loaded_data["PageRank"]
sorted_leaderRank =  loaded_data["LeaderRank"]
sorted_hIndex =  loaded_data["HIndex"]
sorted_kShell=  loaded_data["KShell"]
# 更多的访问可以根据需要添加

# %%
print(sorted_centrality[:3])
print(sorted_pagerank[:3])
print(sorted_leaderRank[:3])
print(sorted_hIndex[:3])
print(sorted_kShell[:3])
# Out:
# [['2481', 0.06522835093524994], ['394', 0.05848059049367236], ['4675', 0.05749815793895991]]
# [['2481', 0.0029730052356006587], ['394', 0.0026745576707996746], ['34', 0.002341799463228293]]
# [['2481', 0.0021783055563750196], ['34', 0.0020590574294100297], ['377', 0.0019739963840719587]]
# [['4675', 267], ['46', 254], ['192', 241]]
# [['8', 106], ['46', 106], ['83', 106]]

# %%
import networkx as nx
import community as community_louvain
import numpy as np

def detect_communities(G):
    """使用Louvain算法检测社区"""
    partition = community_louvain.best_partition(G)
    return partition

def community_aware_ranking_sorted(centrality, partition, budget, alpha=2.2):
    """
    基于已排序的中心性数据进行社区感知排名
    :param centrality: 中心性度量（字典）
    :param partition: 社区划分（字典）
    :param budget: 选择的节点数
    :param alpha: 幂函数分配的参数
    :return: 排名前budget的节点列表
    """
    # 将节点按社区划分
    community_nodes = {}
    for node, community in partition.items():
        if community not in community_nodes:
            community_nodes[community] = []
        community_nodes[community].append(node)

    # 社区内对节点按中心性排序
    for community in community_nodes:
        community_nodes[community].sort(key=lambda node: centrality[node], reverse=True)

    # 计算每个社区的重要性（基于中心性总和）
    community_importance = {}
    for community, nodes in community_nodes.items():
        community_importance[community] = sum(centrality[node] for node in nodes)

    # 总重要性
    total_importance = sum(community_importance.values())

    # 根据社区重要性使用幂函数分配节点名额
    community_budget = {}
    for community, importance in community_importance.items():
        share = (importance / total_importance) ** alpha
        community_budget[community] = int(np.floor(share * budget))

    # 调整总名额分配，确保总数为budget
    total_allocated = sum(community_budget.values())
    while total_allocated != budget:
        for community in community_budget:
            if total_allocated < budget:
                community_budget[community] += 1
                total_allocated += 1
                if total_allocated == budget:
                    break
            elif total_allocated > budget:
                if community_budget[community] > 0:
                    community_budget[community] -= 1
                    total_allocated -= 1
                    if total_allocated == budget:
                        break

    # 选择每个社区中最重要的节点，直到达到预算
    selected_nodes = set()
    for community, nodes in community_nodes.items():
        num_to_select = community_budget[community]
        selected_nodes.update(nodes[:num_to_select])

    return list(selected_nodes)

# %%
import networkx as nx
import community as community_louvain
import matplotlib.pyplot as plt
import numpy as np

def compute_community_importance(graph, communities, partition):
    community_importance = {}
    total_importance = 0

    # 计算桥接节点
    for node in graph.nodes():
        node_community = partition[node]
        neighbors = list(graph.neighbors(node))
        external_neighbors = [neighbor for neighbor in neighbors if partition[neighbor] != node_community]
        
        # 增加社区重要性
        if node_community not in community_importance:
            community_importance[node_community] = 0
        community_importance[node_community] += len(external_neighbors)

    # 加入社区大小
    for community_id, nodes in communities.items():
        if community_id not in community_importance:
            community_importance[community_id] = 0
        community_importance[community_id] += len(nodes)
        total_importance += community_importance[community_id]

    return community_importance, total_importance

def community_aware_centrality_ranking3(graph,partition, centrality, total_budget, alpha=2):
    # 社区检测
    
    communities = {}
    for node, community_id in partition.items():
        if community_id not in communities:
            communities[community_id] = []
        communities[community_id].append(node)
    for community in communities:
        communities[community].sort(key=lambda x: centrality[x], reverse=True)

    # 计算社区重要性并分配预算
    community_importance, total_importance = compute_community_importance(graph, communities, partition)
    
    # Apply power function adjustment for budget allocation
    community_budget = {}
    for community, importance in community_importance.items():
        share = (importance / total_importance) ** alpha
        community_budget[community] = int(round(share * total_budget))

    # Adjust total allocation to ensure total is budget
    total_allocated = sum(community_budget.values())
    while total_allocated != total_budget:
        for community in community_budget:
            if total_allocated < total_budget and community_budget[community] > 0:
                community_budget[community] += 1
                total_allocated += 1
                if total_allocated == total_budget:
                    break
            elif total_allocated > total_budget and community_budget[community] > 0:
                community_budget[community] -= 1
                total_allocated -= 1
                if total_allocated == total_budget:
                    break

    # 选择每个社区中最重要的节点，直到达到预算
    selected_nodes = set()
    for community, budget in community_budget.items():
        selected_nodes.update(communities[community][:budget])

    return list(selected_nodes)

# %%
k_shell = nx.core_number(G)

# %%
leaderRank = leader_rank(G)

# %%
G_edge = nx.read_edgelist('/Users/qing/Desktop/24s1/comp8880/project/code/data/soc/soc-Slashdot0811.txt')  # 加载您的网络数据
#partition = detect_communities(G_edge)

# %%
centrality = nx.degree_centrality(G)

# %%
# 计算并排序度中心性
#degree_centrality = nx.degree_centrality(G)

#leaderRank = leader_rank(G)
# 社区感知排名
budget = 50 # 选择前5个节点

top_nodes_community_aware_connectivity = community_aware_centrality_ranking3(G_edge, partition, centrality, budget)

print("Top nodes selected by community-aware ranking:", top_nodes_community_aware_connectivity)
# Out:
# Top nodes selected by community-aware ranking: ['3882', '46', '8861', '7651', '7462', '3376', '1120', '5900', '871', '2470', '2863', '143', '5421', '1521', '192', '225', '6241', '1825', '5198', '2813', '595', '4884', '4697', '2539', '7669', '2481', '381', '8628', '4668', '5398', '4886', '4675', '4669', '1641', '4699', '6089', '4882', '5715', '3450', '7649', '5107', '217', '5050', '4986', '4875', '5057', '403', '6139', '5245', '5187']

# %%
def plot_sir_simulation(G, sorted_maps, top, infection_prob=0.05, steps=100):
    plt.figure(figsize=(10, 5))

    # Calculate average in-degree
    avg_in_degree = sum(dict(G.in_degree()).values()) / G.number_of_nodes()
    #print(avg_in_degree)
    recovery_prob = 1 / avg_in_degree

    # Iterate through all sorted maps
    for name, sorted_map in sorted_maps.items():
        top_nodes = [node for node, _ in sorted_map[:top]]  # Extract top nodes
        history, ever_infected, infected_counts = SIR_simulation(G, top_nodes, infection_prob, 1, steps)
        plt.plot(infected_counts, marker='o', linestyle='-', label=f'{name}: Top {top}')

    plt.title('Number of Ever Infected Nodes Over Time')
    plt.xlabel('Time Steps')
    plt.ylabel('Number of Ever Infected Nodes')
    plt.grid(True)
    plt.legend()
    plt.show()

def SIR_simulation(G, initial_infected, infection_prob=0.1, recovery_prob=0.05, steps=100):
    # Initialize the status of each node
    status = {node: 'S' for node in G.nodes()}
    for node in initial_infected:
        status[node] = 'I'

    history = []
    ever_infected = set(initial_infected)
    infected_counts = [len(ever_infected)]  # Initial number of infected nodes

    # Simulation process
    for _ in range(steps):
        new_status = status.copy()
        for node in G.nodes():
            if status[node] == 'I':
                for neighbor in G.neighbors(node):
                    if status[neighbor] == 'S' and random.random() < infection_prob:
                        new_status[neighbor] = 'I'
                        ever_infected.add(neighbor)
                if random.random() < recovery_prob:
                    new_status[node] = 'R'
        history.append(new_status)
        status = new_status
        infected_counts.append(len(ever_infected))  # Record the total number of infected nodes

        if not any(s == 'I' for s in status.values()):
            break

    return history, ever_infected, infected_counts

sorted_maps = {
    
    "CommunityAwareConnect": [(node, centrality[node]) for node in top_nodes_community_aware_connectivity],
    #"CommunityAwareCentri": [(node, centrality[node]) for node in top_nodes_community_aware_centrality],
    "Centrality": sorted_centrality,
    #"PageRank": sorted_pagerank,
    #"LeaderRank": sorted_leaderRank,
    #"H-index": sorted_hIndex,
    #"K-Shell": sorted_kShell
}




# 运行模拟并绘图
plot_sir_simulation(G, sorted_maps,top=20, infection_prob=0.015,steps=50)

# %%
# 使用Louvain算法进行社区检测
def detect_communities(G):
    partition = community_louvain.best_partition(G)
    return partition


# 统计前top节点在各社区中的分布
def count_top_nodes_in_communities(G, sorted_maps, top, partition):
    community_counts = {name: {} for name in sorted_maps.keys()}
    
    for name, sorted_map in sorted_maps.items():
        top_nodes = [node for node, _ in sorted_map[:top]]  # 提取前top个节点
        for node in top_nodes:
            community = partition[node]
            if community not in community_counts[name]:
                community_counts[name][community] = 0
            community_counts[name][community] += 1
    
    return community_counts

# 可视化前top节点在各社区中的分布
def plot_top_nodes_distribution(community_counts, top):
    plt.figure(figsize=(15, 10))

    for i, (name, counts) in enumerate(community_counts.items()):
        communities = list(counts.keys())
        counts = list(counts.values())
        
        plt.subplot(3, 3, i + 1)
        plt.bar(communities, counts)
        plt.title(f'Distribution of Top {top} Nodes in Communities\n({name})')
        plt.xlabel('Community')
        plt.ylabel('Number of Top Nodes')

    plt.tight_layout()
    plt.show()

# 统计每个社区的节点数量并排序
def count_and_sort_communities(partition):
    community_counts = {}
    for node, community in partition.items():
        if community not in community_counts:
            community_counts[community] = 0
        community_counts[community] += 1
    
    # 按照节点数量排序社区
    sorted_community_counts = sorted(community_counts.items(), key=lambda x: x[1], reverse=True)
    return sorted_community_counts

# %%
# 示例：检测社区并统计前top节点的分布
G_edge = nx.read_edgelist('/Users/qing/Desktop/24s1/comp8880/project/code/data/soc/soc-Slashdot0811.txt')  # 加载您的网络数据
partition = detect_communities(G_edge)

# %%
partition_file = 'saved/partition_slash.json'

# %%
partition_file = 'saved/partition_slash.json'
with open(partition_file, 'w') as f:
    json.dump(partition, f)

# %%
print(f"Partition saved to {partition_file}")

# 从 JSON 文件加载分区
with open(partition_file, 'r') as f:
    partition = json.load(f)
# Out:
# Partition saved to saved/partition_slash.json

# %%
top = 50
community_counts = count_top_nodes_in_communities(G_edge, sorted_maps, top, partition)
plot_top_nodes_distribution(community_counts, top)

# %%
sorted_community_counts = count_and_sort_communities(partition)

for community, count in sorted_community_counts:
    print(f"Community {community}: {count} nodes")
# Out:
# Community 4: 15937 nodes
# Community 1: 12365 nodes
# Community 2: 8459 nodes
# Community 0: 7736 nodes
# Community 7: 3271 nodes
# Community 3: 2018 nodes
# Community 8: 1350 nodes
# Community 29: 1305 nodes
# Community 23: 1195 nodes
# Community 15: 1053 nodes
# Community 21: 998 nodes
# Community 9: 947 nodes
# Community 26: 940 nodes
# Community 13: 815 nodes
# Community 24: 777 nodes
# Community 20: 628 nodes
# Community 10: 605 nodes
# Community 28: 568 nodes
# Community 5: 548 nodes
# Community 12: 537 nodes
# Community 33: 537 nodes
# Community 16: 534 nodes
# Community 19: 466 nodes
# Community 40: 466 nodes
# Community 45: 455 nodes
# Community 6: 453 nodes
# Community 22: 440 nodes
# Community 44: 436 nodes
# Community 42: 415 nodes
# Community 43: 390 nodes
# Community 55: 367 nodes
# Community 27: 357 nodes
# Community 14: 355 nodes
# Community 50: 345 nodes
# Community 36: 333 nodes
# Community 48: 333 nodes
# Community 46: 331 nodes
# Community 58: 326 nodes
# Community 60: 296 nodes
# Community 49: 257 nodes
# Community 61: 233 nodes
# Community 18: 230 nodes
# Community 47: 228 nodes
# Community 51: 219 nodes
# Community 37: 218 nodes
# Community 52: 216 nodes
# Community 32: 209 nodes
# Community 65: 203 nodes
# Community 68: 198 nodes
# Community 34: 190 nodes
# Community 30: 189 nodes
# Community 41: 179 nodes
# Community 38: 171 nodes
# Community 56: 167 nodes
# Community 25: 149 nodes
# Community 67: 123 nodes
# Community 39: 118 nodes
# Community 54: 112 nodes
# Community 62: 82 nodes
# Community 11: 75 nodes
# Community 136: 25 nodes
# Community 192: 24 nodes
# Community 63: 20 nodes
# Community 35: 18 nodes
# Community 78: 18 nodes
# Community 171: 16 nodes
# Community 1486: 16 nodes
# Community 113: 13 nodes
# Community 678: 13 nodes
# Community 206: 12 nodes
# Community 176: 11 nodes
# Community 497: 10 nodes
# Community 503: 10 nodes
# Community 944: 10 nodes
# Community 671: 9 nodes
# Community 732: 9 nodes
# Community 1307: 9 nodes
# Community 1336: 9 nodes
# Community 170: 8 nodes
# Community 183: 8 nodes
# Community 702: 8 nodes
# Community 772: 8 nodes
# Community 57: 7 nodes
# Community 154: 7 nodes
# Community 237: 7 nodes
# Community 250: 7 nodes
# Community 266: 7 nodes
# Community 306: 7 nodes
# Community 367: 7 nodes
# Community 453: 7 nodes
# Community 457: 7 nodes
# Community 459: 7 nodes
# Community 539: 7 nodes
# Community 644: 7 nodes
# Community 698: 7 nodes
# Community 1155: 7 nodes
# Community 1341: 7 nodes
# Community 119: 6 nodes
# Community 134: 6 nodes
# Community 139: 6 nodes
# Community 149: 6 nodes
# Community 163: 6 nodes
# Community 186: 6 nodes
# Community 196: 6 nodes
# Community 210: 6 nodes
# Community 289: 6 nodes
# Community 292: 6 nodes
# Community 454: 6 nodes
# Community 525: 6 nodes
# Community 627: 6 nodes
# Community 663: 6 nodes
# Community 696: 6 nodes
# Community 720: 6 nodes
# Community 729: 6 nodes
# Community 744: 6 nodes
# Community 950: 6 nodes
# Community 1183: 6 nodes
# Community 1356: 6 nodes
# Community 59: 5 nodes
# Community 69: 5 nodes
# Community 74: 5 nodes
# Community 87: 5 nodes
# Community 100: 5 nodes
# Community 130: 5 nodes
# Community 152: 5 nodes
# Community 155: 5 nodes
# Community 172: 5 nodes
# Community 174: 5 nodes
# Community 177: 5 nodes
# Community 201: 5 nodes
# Community 213: 5 nodes
# Community 244: 5 nodes
# Community 267: 5 nodes
# Community 320: 5 nodes
# Community 326: 5 nodes
# Community 348: 5 nodes
# Community 378: 5 nodes
# Community 386: 5 nodes
# Community 406: 5 nodes
# Community 408: 5 nodes
# Community 434: 5 nodes
# Community 435: 5 nodes
# Community 458: 5 nodes
# Community 526: 5 nodes
# Community 558: 5 nodes
# Community 584: 5 nodes
# Community 587: 5 nodes
# Community 604: 5 nodes
# Community 612: 5 nodes
# Community 639: 5 nodes
# Community 655: 5 nodes
# Community 756: 5 nodes
# Community 799: 5 nodes
# Community 849: 5 nodes
# Community 904: 5 nodes
# Community 905: 5 nodes
# Community 948: 5 nodes
# Community 1099: 5 nodes
# Community 1195: 5 nodes
# Community 1224: 5 nodes
# Community 1242: 5 nodes
# Community 1293: 5 nodes
# Community 1303: 5 nodes
# Community 1364: 5 nodes
# Community 1372: 5 nodes
# Community 1384: 5 nodes
# Community 1450: 5 nodes
# Community 1458: 5 nodes
# Community 53: 4 nodes
# Community 66: 4 nodes
# Community 85: 4 nodes
# Community 94: 4 nodes
# Community 95: 4 nodes
# Community 106: 4 nodes
# Community 120: 4 nodes
# Community 124: 4 nodes
# Community 135: 4 nodes
# Community 146: 4 nodes
# Community 156: 4 nodes
# Community 162: 4 nodes
# Community 175: 4 nodes
# Community 188: 4 nodes
# Community 189: 4 nodes
# Community 191: 4 nodes
# Community 195: 4 nodes
# Community 199: 4 nodes
# Community 214: 4 nodes
# Community 216: 4 nodes
# Community 219: 4 nodes
# Community 221: 4 nodes
# Community 227: 4 nodes
# Community 229: 4 nodes
# Community 236: 4 nodes
# Community 239: 4 nodes
# Community 246: 4 nodes
# Community 248: 4 nodes
# Community 249: 4 nodes
# Community 256: 4 nodes
# Community 258: 4 nodes
# Community 259: 4 nodes
# Community 264: 4 nodes
# Community 274: 4 nodes
# Community 275: 4 nodes
# Community 280: 4 nodes
# Community 281: 4 nodes
# Community 302: 4 nodes
# Community 316: 4 nodes
# Community 333: 4 nodes
# Community 343: 4 nodes
# Community 354: 4 nodes
# Community 363: 4 nodes
# Community 377: 4 nodes
# Community 403: 4 nodes
# Community 420: 4 nodes
# Community 427: 4 nodes
# Community 437: 4 nodes
# Community 440: 4 nodes
# Community 442: 4 nodes
# Community 448: 4 nodes
# Community 449: 4 nodes
# Community 462: 4 nodes
# Community 473: 4 nodes
# Community 480: 4 nodes
# Community 507: 4 nodes
# Community 516: 4 nodes
# Community 540: 4 nodes
# Community 541: 4 nodes
# Community 555: 4 nodes
# Community 626: 4 nodes
# Community 706: 4 nodes
# Community 709: 4 nodes
# Community 719: 4 nodes
# Community 749: 4 nodes
# Community 750: 4 nodes
# Community 763: 4 nodes
# Community 777: 4 nodes
# Community 782: 4 nodes
# Community 783: 4 nodes
# Community 807: 4 nodes
# Community 831: 4 nodes
# Community 858: 4 nodes
# Community 869: 4 nodes
# Community 873: 4 nodes
# Community 902: 4 nodes
# Community 931: 4 nodes
# Community 959: 4 nodes
# Community 971: 4 nodes
# Community 988: 4 nodes
# Community 991: 4 nodes
# Community 994: 4 nodes
# Community 1001: 4 nodes
# Community 1061: 4 nodes
# Community 1094: 4 nodes
# Community 1116: 4 nodes
# Community 1136: 4 nodes
# Community 1178: 4 nodes
# Community 1204: 4 nodes
# Community 1218: 4 nodes
# Community 1225: 4 nodes
# Community 1234: 4 nodes
# Community 1245: 4 nodes
# Community 1288: 4 nodes
# Community 1313: 4 nodes
# Community 1317: 4 nodes
# Community 1327: 4 nodes
# Community 1340: 4 nodes
# Community 1358: 4 nodes
# Community 1360: 4 nodes
# Community 1370: 4 nodes
# Community 1440: 4 nodes
# Community 1459: 4 nodes
# Community 1468: 4 nodes
# Community 1478: 4 nodes
# Community 1491: 4 nodes
# Community 1512: 4 nodes
# Community 64: 3 nodes
# Community 72: 3 nodes
# Community 82: 3 nodes
# Community 86: 3 nodes
# Community 91: 3 nodes
# Community 92: 3 nodes
# Community 97: 3 nodes
# Community 99: 3 nodes
# Community 103: 3 nodes
# Community 107: 3 nodes
# Community 109: 3 nodes
# Community 111: 3 nodes
# Community 114: 3 nodes
# Community 116: 3 nodes
# Community 121: 3 nodes
# Community 126: 3 nodes
# Community 128: 3 nodes
# Community 129: 3 nodes
# Community 131: 3 nodes
# Community 132: 3 nodes
# Community 133: 3 nodes
# Community 137: 3 nodes
# Community 140: 3 nodes
# Community 141: 3 nodes
# Community 143: 3 nodes
# Community 145: 3 nodes
# Community 148: 3 nodes
# Community 157: 3 nodes
# Community 159: 3 nodes
# Community 165: 3 nodes
# Community 166: 3 nodes
# Community 167: 3 nodes
# Community 169: 3 nodes
# Community 180: 3 nodes
# Community 185: 3 nodes
# Community 187: 3 nodes
# Community 190: 3 nodes
# Community 193: 3 nodes
# Community 194: 3 nodes
# Community 197: 3 nodes
# Community 198: 3 nodes
# Community 207: 3 nodes
# Community 220: 3 nodes
# Community 228: 3 nodes
# Community 230: 3 nodes
# Community 231: 3 nodes
# Community 235: 3 nodes
# Community 238: 3 nodes
# Community 253: 3 nodes
# Community 255: 3 nodes
# Community 261: 3 nodes
# Community 263: 3 nodes
# Community 268: 3 nodes
# Community 269: 3 nodes
# Community 270: 3 nodes
# Community 273: 3 nodes
# Community 277: 3 nodes
# Community 279: 3 nodes
# Community 286: 3 nodes
# Community 296: 3 nodes
# Community 300: 3 nodes
# Community 305: 3 nodes
# Community 307: 3 nodes
# Community 312: 3 nodes
# Community 321: 3 nodes
# Community 324: 3 nodes
# Community 336: 3 nodes
# Community 340: 3 nodes
# Community 341: 3 nodes
# Community 342: 3 nodes
# Community 351: 3 nodes
# Community 352: 3 nodes
# Community 355: 3 nodes
# Community 358: 3 nodes
# Community 359: 3 nodes
# Community 360: 3 nodes
# Community 362: 3 nodes
# Community 368: 3 nodes
# Community 379: 3 nodes
# Community 382: 3 nodes
# Community 385: 3 nodes
# Community 387: 3 nodes
# Community 388: 3 nodes
# Community 392: 3 nodes
# Community 393: 3 nodes
# Community 394: 3 nodes
# Community 398: 3 nodes
# Community 400: 3 nodes
# Community 405: 3 nodes
# Community 407: 3 nodes
# Community 411: 3 nodes
# Community 424: 3 nodes
# Community 431: 3 nodes
# Community 438: 3 nodes
# Community 444: 3 nodes
# Community 445: 3 nodes
# Community 446: 3 nodes
# Community 452: 3 nodes
# Community 455: 3 nodes
# Community 456: 3 nodes
# Community 464: 3 nodes
# Community 465: 3 nodes
# Community 467: 3 nodes
# Community 478: 3 nodes
# Community 479: 3 nodes
# Community 481: 3 nodes
# Community 487: 3 nodes
# Community 488: 3 nodes
# Community 490: 3 nodes
# Community 493: 3 nodes
# Community 498: 3 nodes
# Community 499: 3 nodes
# Community 500: 3 nodes
# Community 509: 3 nodes
# Community 513: 3 nodes
# Community 518: 3 nodes
# Community 522: 3 nodes
# Community 523: 3 nodes
# Community 535: 3 nodes
# Community 547: 3 nodes
# Community 549: 3 nodes
# Community 552: 3 nodes
# Community 554: 3 nodes
# Community 557: 3 nodes
# Community 564: 3 nodes
# Community 565: 3 nodes
# Community 568: 3 nodes
# Community 573: 3 nodes
# Community 577: 3 nodes
# Community 595: 3 nodes
# Community 600: 3 nodes
# Community 615: 3 nodes
# Community 619: 3 nodes
# Community 620: 3 nodes
# Community 623: 3 nodes
# Community 631: 3 nodes
# Community 632: 3 nodes
# Community 634: 3 nodes
# Community 636: 3 nodes
# Community 647: 3 nodes
# Community 653: 3 nodes
# Community 666: 3 nodes
# Community 667: 3 nodes
# Community 668: 3 nodes
# Community 676: 3 nodes
# Community 679: 3 nodes
# Community 680: 3 nodes
# Community 682: 3 nodes
# Community 684: 3 nodes
# Community 689: 3 nodes
# Community 692: 3 nodes
# Community 694: 3 nodes
# Community 695: 3 nodes
# Community 697: 3 nodes
# Community 700: 3 nodes
# Community 711: 3 nodes
# Community 713: 3 nodes
# Community 714: 3 nodes
# Community 717: 3 nodes
# Community 718: 3 nodes
# Community 726: 3 nodes
# Community 727: 3 nodes
# Community 728: 3 nodes
# Community 733: 3 nodes
# Community 736: 3 nodes
# Community 737: 3 nodes
# Community 738: 3 nodes
# Community 743: 3 nodes
# Community 751: 3 nodes
# Community 752: 3 nodes
# Community 753: 3 nodes
# Community 755: 3 nodes
# Community 759: 3 nodes
# Community 760: 3 nodes
# Community 761: 3 nodes
# Community 764: 3 nodes
# Community 767: 3 nodes
# Community 778: 3 nodes
# Community 779: 3 nodes
# Community 788: 3 nodes
# Community 794: 3 nodes
# Community 798: 3 nodes
# Community 806: 3 nodes
# Community 808: 3 nodes
# Community 812: 3 nodes
# Community 814: 3 nodes
# Community 815: 3 nodes
# Community 824: 3 nodes
# Community 834: 3 nodes
# Community 838: 3 nodes
# Community 841: 3 nodes
# Community 843: 3 nodes
# Community 844: 3 nodes
# Community 845: 3 nodes
# Community 855: 3 nodes
# Community 862: 3 nodes
# Community 865: 3 nodes
# Community 868: 3 nodes
# Community 884: 3 nodes
# Community 889: 3 nodes
# Community 890: 3 nodes
# Community 892: 3 nodes
# Community 898: 3 nodes
# Community 899: 3 nodes
# Community 901: 3 nodes
# Community 909: 3 nodes
# Community 911: 3 nodes
# Community 912: 3 nodes
# Community 916: 3 nodes
# Community 918: 3 nodes
# Community 925: 3 nodes
# Community 930: 3 nodes
# Community 937: 3 nodes
# Community 943: 3 nodes
# Community 951: 3 nodes
# Community 952: 3 nodes
# Community 964: 3 nodes
# Community 966: 3 nodes
# Community 970: 3 nodes
# Community 978: 3 nodes
# Community 980: 3 nodes
# Community 984: 3 nodes
# Community 985: 3 nodes
# Community 998: 3 nodes
# Community 1008: 3 nodes
# Community 1016: 3 nodes
# Community 1019: 3 nodes
# Community 1024: 3 nodes
# Community 1035: 3 nodes
# Community 1040: 3 nodes
# Community 1043: 3 nodes
# Community 1047: 3 nodes
# Community 1048: 3 nodes
# Community 1055: 3 nodes
# Community 1069: 3 nodes
# Community 1073: 3 nodes
# Community 1076: 3 nodes
# Community 1082: 3 nodes
# Community 1084: 3 nodes
# Community 1093: 3 nodes
# Community 1095: 3 nodes
# Community 1101: 3 nodes
# Community 1104: 3 nodes
# Community 1108: 3 nodes
# Community 1117: 3 nodes
# Community 1129: 3 nodes
# Community 1131: 3 nodes
# Community 1133: 3 nodes
# Community 1139: 3 nodes
# Community 1141: 3 nodes
# Community 1142: 3 nodes
# Community 1152: 3 nodes
# Community 1159: 3 nodes
# Community 1185: 3 nodes
# Community 1187: 3 nodes
# Community 1192: 3 nodes
# Community 1201: 3 nodes
# Community 1202: 3 nodes
# Community 1205: 3 nodes
# Community 1207: 3 nodes
# Community 1211: 3 nodes
# Community 1213: 3 nodes
# Community 1226: 3 nodes
# Community 1235: 3 nodes
# Community 1239: 3 nodes
# Community 1243: 3 nodes
# Community 1249: 3 nodes
# Community 1254: 3 nodes
# Community 1258: 3 nodes
# Community 1260: 3 nodes
# Community 1265: 3 nodes
# Community 1268: 3 nodes
# Community 1269: 3 nodes
# Community 1271: 3 nodes
# Community 1276: 3 nodes
# Community 1277: 3 nodes
# Community 1282: 3 nodes
# Community 1294: 3 nodes
# Community 1300: 3 nodes
# Community 1304: 3 nodes
# Community 1312: 3 nodes
# Community 1315: 3 nodes
# Community 1332: 3 nodes
# Community 1334: 3 nodes
# Community 1335: 3 nodes
# Community 1339: 3 nodes
# Community 1350: 3 nodes
# Community 1352: 3 nodes
# Community 1359: 3 nodes
# Community 1363: 3 nodes
# Community 1366: 3 nodes
# Community 1369: 3 nodes
# Community 1376: 3 nodes
# Community 1378: 3 nodes
# Community 1382: 3 nodes
# Community 1383: 3 nodes
# Community 1388: 3 nodes
# Community 1392: 3 nodes
# Community 1400: 3 nodes
# Community 1421: 3 nodes
# Community 1429: 3 nodes
# Community 1431: 3 nodes
# Community 1433: 3 nodes
# Community 1446: 3 nodes
# Community 1454: 3 nodes
# Community 1455: 3 nodes
# Community 1457: 3 nodes
# Community 1462: 3 nodes
# Community 1471: 3 nodes
# Community 1487: 3 nodes
# Community 1489: 3 nodes
# Community 1496: 3 nodes
# Community 1505: 3 nodes
# Community 1520: 3 nodes
# Community 1524: 3 nodes
# Community 31: 2 nodes
# Community 70: 2 nodes
# Community 71: 2 nodes
# Community 73: 2 nodes
# Community 75: 2 nodes
# Community 76: 2 nodes
# Community 77: 2 nodes
# Community 79: 2 nodes
# Community 80: 2 nodes
# Community 81: 2 nodes
# Community 83: 2 nodes
# Community 88: 2 nodes
# Community 89: 2 nodes
# Community 90: 2 nodes
# Community 93: 2 nodes
# Community 96: 2 nodes
# Community 101: 2 nodes
# Community 104: 2 nodes
# Community 105: 2 nodes
# Community 112: 2 nodes
# Community 115: 2 nodes
# Community 117: 2 nodes
# Community 118: 2 nodes
# Community 122: 2 nodes
# Community 123: 2 nodes
# Community 125: 2 nodes
# Community 127: 2 nodes
# Community 138: 2 nodes
# Community 142: 2 nodes
# Community 144: 2 nodes
# Community 147: 2 nodes
# Community 150: 2 nodes
# Community 151: 2 nodes
# Community 153: 2 nodes
# Community 158: 2 nodes
# Community 160: 2 nodes
# Community 161: 2 nodes
# Community 164: 2 nodes
# Community 168: 2 nodes
# Community 178: 2 nodes
# Community 179: 2 nodes
# Community 181: 2 nodes
# Community 182: 2 nodes
# Community 184: 2 nodes
# Community 200: 2 nodes
# Community 202: 2 nodes
# Community 203: 2 nodes
# Community 204: 2 nodes
# Community 205: 2 nodes
# Community 208: 2 nodes
# Community 209: 2 nodes
# Community 211: 2 nodes
# Community 212: 2 nodes
# Community 215: 2 nodes
# Community 217: 2 nodes
# Community 218: 2 nodes
# Community 222: 2 nodes
# Community 223: 2 nodes
# Community 224: 2 nodes
# Community 225: 2 nodes
# Community 226: 2 nodes
# Community 233: 2 nodes
# Community 240: 2 nodes
# Community 241: 2 nodes
# Community 242: 2 nodes
# Community 243: 2 nodes
# Community 245: 2 nodes
# Community 247: 2 nodes
# Community 251: 2 nodes
# Community 252: 2 nodes
# Community 254: 2 nodes
# Community 257: 2 nodes
# Community 260: 2 nodes
# Community 262: 2 nodes
# Community 265: 2 nodes
# Community 271: 2 nodes
# Community 272: 2 nodes
# Community 276: 2 nodes
# Community 278: 2 nodes
# Community 282: 2 nodes
# Community 283: 2 nodes
# Community 284: 2 nodes
# Community 285: 2 nodes
# Community 287: 2 nodes
# Community 288: 2 nodes
# Community 290: 2 nodes
# Community 294: 2 nodes
# Community 295: 2 nodes
# Community 297: 2 nodes
# Community 298: 2 nodes
# Community 299: 2 nodes
# Community 303: 2 nodes
# Community 304: 2 nodes
# Community 308: 2 nodes
# Community 309: 2 nodes
# Community 311: 2 nodes
# Community 313: 2 nodes
# Community 314: 2 nodes
# Community 315: 2 nodes
# Community 317: 2 nodes
# Community 318: 2 nodes
# Community 319: 2 nodes
# Community 322: 2 nodes
# Community 323: 2 nodes
# Community 325: 2 nodes
# Community 327: 2 nodes
# Community 328: 2 nodes
# Community 329: 2 nodes
# Community 330: 2 nodes
# Community 331: 2 nodes
# Community 334: 2 nodes
# Community 335: 2 nodes
# Community 337: 2 nodes
# Community 338: 2 nodes
# Community 339: 2 nodes
# Community 344: 2 nodes
# Community 345: 2 nodes
# Community 346: 2 nodes
# Community 347: 2 nodes
# Community 349: 2 nodes
# Community 350: 2 nodes
# Community 353: 2 nodes
# Community 356: 2 nodes
# Community 357: 2 nodes
# Community 364: 2 nodes
# Community 365: 2 nodes
# Community 366: 2 nodes
# Community 369: 2 nodes
# Community 371: 2 nodes
# Community 372: 2 nodes
# Community 373: 2 nodes
# Community 374: 2 nodes
# Community 376: 2 nodes
# Community 380: 2 nodes
# Community 381: 2 nodes
# Community 383: 2 nodes
# Community 384: 2 nodes
# Community 389: 2 nodes
# Community 390: 2 nodes
# Community 395: 2 nodes
# Community 396: 2 nodes
# Community 397: 2 nodes
# Community 399: 2 nodes
# Community 402: 2 nodes
# Community 404: 2 nodes
# Community 409: 2 nodes
# Community 412: 2 nodes
# Community 413: 2 nodes
# Community 414: 2 nodes
# Community 415: 2 nodes
# Community 416: 2 nodes
# Community 417: 2 nodes
# Community 418: 2 nodes
# Community 419: 2 nodes
# Community 421: 2 nodes
# Community 423: 2 nodes
# Community 425: 2 nodes
# Community 426: 2 nodes
# Community 428: 2 nodes
# Community 429: 2 nodes
# Community 430: 2 nodes
# Community 432: 2 nodes
# Community 433: 2 nodes
# Community 436: 2 nodes
# Community 439: 2 nodes
# Community 441: 2 nodes
# Community 443: 2 nodes
# Community 447: 2 nodes
# Community 450: 2 nodes
# Community 451: 2 nodes
# Community 460: 2 nodes
# Community 461: 2 nodes
# Community 466: 2 nodes
# Community 469: 2 nodes
# Community 470: 2 nodes
# Community 471: 2 nodes
# Community 472: 2 nodes
# Community 474: 2 nodes
# Community 475: 2 nodes
# Community 476: 2 nodes
# Community 477: 2 nodes
# Community 482: 2 nodes
# Community 483: 2 nodes
# Community 484: 2 nodes
# Community 485: 2 nodes
# Community 489: 2 nodes
# Community 491: 2 nodes
# Community 492: 2 nodes
# Community 494: 2 nodes
# Community 495: 2 nodes
# Community 501: 2 nodes
# Community 502: 2 nodes
# Community 504: 2 nodes
# Community 505: 2 nodes
# Community 506: 2 nodes
# Community 508: 2 nodes
# Community 510: 2 nodes
# Community 511: 2 nodes
# Community 512: 2 nodes
# Community 515: 2 nodes
# Community 517: 2 nodes
# Community 519: 2 nodes
# Community 520: 2 nodes
# Community 521: 2 nodes
# Community 527: 2 nodes
# Community 528: 2 nodes
# Community 529: 2 nodes
# Community 530: 2 nodes
# Community 531: 2 nodes
# Community 532: 2 nodes
# Community 533: 2 nodes
# Community 534: 2 nodes
# Community 536: 2 nodes
# Community 537: 2 nodes
# Community 538: 2 nodes
# Community 542: 2 nodes
# Community 544: 2 nodes
# Community 545: 2 nodes
# Community 546: 2 nodes
# Community 548: 2 nodes
# Community 550: 2 nodes
# Community 551: 2 nodes
# Community 553: 2 nodes
# Community 559: 2 nodes
# Community 560: 2 nodes
# Community 561: 2 nodes
# Community 563: 2 nodes
# Community 566: 2 nodes
# Community 567: 2 nodes
# Community 569: 2 nodes
# Community 570: 2 nodes
# Community 571: 2 nodes
# Community 572: 2 nodes
# Community 574: 2 nodes
# Community 575: 2 nodes
# Community 576: 2 nodes
# Community 578: 2 nodes
# Community 579: 2 nodes
# Community 580: 2 nodes
# Community 581: 2 nodes
# Community 582: 2 nodes
# Community 583: 2 nodes
# Community 586: 2 nodes
# Community 588: 2 nodes
# Community 590: 2 nodes
# Community 591: 2 nodes
# Community 592: 2 nodes
# Community 593: 2 nodes
# Community 594: 2 nodes
# Community 596: 2 nodes
# Community 597: 2 nodes
# Community 598: 2 nodes
# Community 599: 2 nodes
# Community 601: 2 nodes
# Community 602: 2 nodes
# Community 603: 2 nodes
# Community 605: 2 nodes
# Community 607: 2 nodes
# Community 609: 2 nodes
# Community 611: 2 nodes
# Community 616: 2 nodes
# Community 617: 2 nodes
# Community 618: 2 nodes
# Community 622: 2 nodes
# Community 624: 2 nodes
# Community 625: 2 nodes
# Community 628: 2 nodes
# Community 629: 2 nodes
# Community 630: 2 nodes
# Community 633: 2 nodes
# Community 638: 2 nodes
# Community 640: 2 nodes
# Community 642: 2 nodes
# Community 643: 2 nodes
# Community 646: 2 nodes
# Community 648: 2 nodes
# Community 649: 2 nodes
# Community 650: 2 nodes
# Community 652: 2 nodes
# Community 656: 2 nodes
# Community 657: 2 nodes
# Community 658: 2 nodes
# Community 659: 2 nodes
# Community 660: 2 nodes
# Community 661: 2 nodes
# Community 662: 2 nodes
# Community 664: 2 nodes
# Community 665: 2 nodes
# Community 669: 2 nodes
# Community 670: 2 nodes
# Community 672: 2 nodes
# Community 673: 2 nodes
# Community 674: 2 nodes
# Community 677: 2 nodes
# Community 681: 2 nodes
# Community 685: 2 nodes
# Community 686: 2 nodes
# Community 688: 2 nodes
# Community 690: 2 nodes
# Community 691: 2 nodes
# Community 693: 2 nodes
# Community 699: 2 nodes
# Community 701: 2 nodes
# Community 703: 2 nodes
# Community 704: 2 nodes
# Community 705: 2 nodes
# Community 707: 2 nodes
# Community 708: 2 nodes
# Community 710: 2 nodes
# Community 715: 2 nodes
# Community 716: 2 nodes
# Community 721: 2 nodes
# Community 722: 2 nodes
# Community 723: 2 nodes
# Community 724: 2 nodes
# Community 725: 2 nodes
# Community 730: 2 nodes
# Community 731: 2 nodes
# Community 734: 2 nodes
# Community 739: 2 nodes
# Community 740: 2 nodes
# Community 741: 2 nodes
# Community 742: 2 nodes
# Community 745: 2 nodes
# Community 747: 2 nodes
# Community 748: 2 nodes
# Community 754: 2 nodes
# Community 757: 2 nodes
# Community 758: 2 nodes
# Community 762: 2 nodes
# Community 766: 2 nodes
# Community 769: 2 nodes
# Community 770: 2 nodes
# Community 771: 2 nodes
# Community 773: 2 nodes
# Community 774: 2 nodes
# Community 775: 2 nodes
# Community 776: 2 nodes
# Community 780: 2 nodes
# Community 781: 2 nodes
# Community 784: 2 nodes
# Community 785: 2 nodes
# Community 786: 2 nodes
# Community 787: 2 nodes
# Community 790: 2 nodes
# Community 792: 2 nodes
# Community 793: 2 nodes
# Community 795: 2 nodes
# Community 796: 2 nodes
# Community 797: 2 nodes
# Community 800: 2 nodes
# Community 801: 2 nodes
# Community 802: 2 nodes
# Community 803: 2 nodes
# Community 804: 2 nodes
# Community 805: 2 nodes
# Community 809: 2 nodes
# Community 810: 2 nodes
# Community 811: 2 nodes
# Community 813: 2 nodes
# Community 816: 2 nodes
# Community 818: 2 nodes
# Community 819: 2 nodes
# Community 820: 2 nodes
# Community 821: 2 nodes
# Community 822: 2 nodes
# Community 823: 2 nodes
# Community 825: 2 nodes
# Community 826: 2 nodes
# Community 827: 2 nodes
# Community 828: 2 nodes
# Community 829: 2 nodes
# Community 830: 2 nodes
# Community 832: 2 nodes
# Community 835: 2 nodes
# Community 837: 2 nodes
# Community 839: 2 nodes
# Community 840: 2 nodes
# Community 842: 2 nodes
# Community 846: 2 nodes
# Community 847: 2 nodes
# Community 848: 2 nodes
# Community 850: 2 nodes
# Community 851: 2 nodes
# Community 852: 2 nodes
# Community 854: 2 nodes
# Community 856: 2 nodes
# Community 857: 2 nodes
# Community 859: 2 nodes
# Community 860: 2 nodes
# Community 861: 2 nodes
# Community 863: 2 nodes
# Community 864: 2 nodes
# Community 867: 2 nodes
# Community 870: 2 nodes
# Community 871: 2 nodes
# Community 872: 2 nodes
# Community 874: 2 nodes
# Community 875: 2 nodes
# Community 876: 2 nodes
# Community 877: 2 nodes
# Community 878: 2 nodes
# Community 879: 2 nodes
# Community 880: 2 nodes
# Community 882: 2 nodes
# Community 883: 2 nodes
# Community 885: 2 nodes
# Community 886: 2 nodes
# Community 887: 2 nodes
# Community 888: 2 nodes
# Community 891: 2 nodes
# Community 893: 2 nodes
# Community 895: 2 nodes
# Community 896: 2 nodes
# Community 900: 2 nodes
# Community 903: 2 nodes
# Community 906: 2 nodes
# Community 907: 2 nodes
# Community 910: 2 nodes
# Community 913: 2 nodes
# Community 914: 2 nodes
# Community 915: 2 nodes
# Community 919: 2 nodes
# Community 920: 2 nodes
# Community 921: 2 nodes
# Community 922: 2 nodes
# Community 923: 2 nodes
# Community 926: 2 nodes
# Community 927: 2 nodes
# Community 928: 2 nodes
# Community 932: 2 nodes
# Community 933: 2 nodes
# Community 934: 2 nodes
# Community 935: 2 nodes
# Community 938: 2 nodes
# Community 939: 2 nodes
# Community 940: 2 nodes
# Community 941: 2 nodes
# Community 942: 2 nodes
# Community 945: 2 nodes
# Community 946: 2 nodes
# Community 947: 2 nodes
# Community 949: 2 nodes
# Community 953: 2 nodes
# Community 954: 2 nodes
# Community 955: 2 nodes
# Community 956: 2 nodes
# Community 958: 2 nodes
# Community 960: 2 nodes
# Community 961: 2 nodes
# Community 962: 2 nodes
# Community 963: 2 nodes
# Community 967: 2 nodes
# Community 968: 2 nodes
# Community 972: 2 nodes
# Community 973: 2 nodes
# Community 974: 2 nodes
# Community 975: 2 nodes
# Community 976: 2 nodes
# Community 977: 2 nodes
# Community 979: 2 nodes
# Community 981: 2 nodes
# Community 982: 2 nodes
# Community 983: 2 nodes
# Community 987: 2 nodes
# Community 989: 2 nodes
# Community 990: 2 nodes
# Community 992: 2 nodes
# Community 993: 2 nodes
# Community 995: 2 nodes
# Community 996: 2 nodes
# Community 997: 2 nodes
# Community 999: 2 nodes
# Community 1002: 2 nodes
# Community 1004: 2 nodes
# Community 1005: 2 nodes
# Community 1006: 2 nodes
# Community 1007: 2 nodes
# Community 1010: 2 nodes
# Community 1011: 2 nodes
# Community 1012: 2 nodes
# Community 1013: 2 nodes
# Community 1014: 2 nodes
# Community 1015: 2 nodes
# Community 1017: 2 nodes
# Community 1018: 2 nodes
# Community 1020: 2 nodes
# Community 1021: 2 nodes
# Community 1022: 2 nodes
# Community 1023: 2 nodes
# Community 1025: 2 nodes
# Community 1026: 2 nodes
# Community 1027: 2 nodes
# Community 1028: 2 nodes
# Community 1029: 2 nodes
# Community 1030: 2 nodes
# Community 1032: 2 nodes
# Community 1033: 2 nodes
# Community 1036: 2 nodes
# Community 1037: 2 nodes
# Community 1038: 2 nodes
# Community 1041: 2 nodes
# Community 1042: 2 nodes
# Community 1044: 2 nodes
# Community 1045: 2 nodes
# Community 1046: 2 nodes
# Community 1051: 2 nodes
# Community 1052: 2 nodes
# Community 1053: 2 nodes
# Community 1054: 2 nodes
# Community 1056: 2 nodes
# Community 1057: 2 nodes
# Community 1058: 2 nodes
# Community 1059: 2 nodes
# Community 1060: 2 nodes
# Community 1062: 2 nodes
# Community 1063: 2 nodes
# Community 1064: 2 nodes
# Community 1065: 2 nodes
# Community 1066: 2 nodes
# Community 1067: 2 nodes
# Community 1068: 2 nodes
# Community 1070: 2 nodes
# Community 1071: 2 nodes
# Community 1072: 2 nodes
# Community 1074: 2 nodes
# Community 1077: 2 nodes
# Community 1078: 2 nodes
# Community 1079: 2 nodes
# Community 1080: 2 nodes
# Community 1081: 2 nodes
# Community 1083: 2 nodes
# Community 1085: 2 nodes
# Community 1086: 2 nodes
# Community 1088: 2 nodes
# Community 1089: 2 nodes
# Community 1090: 2 nodes
# Community 1091: 2 nodes
# Community 1092: 2 nodes
# Community 1096: 2 nodes
# Community 1097: 2 nodes
# Community 1102: 2 nodes
# Community 1103: 2 nodes
# Community 1105: 2 nodes
# Community 1106: 2 nodes
# Community 1107: 2 nodes
# Community 1109: 2 nodes
# Community 1110: 2 nodes
# Community 1111: 2 nodes
# Community 1112: 2 nodes
# Community 1114: 2 nodes
# Community 1115: 2 nodes
# Community 1119: 2 nodes
# Community 1120: 2 nodes
# Community 1121: 2 nodes
# Community 1123: 2 nodes
# Community 1124: 2 nodes
# Community 1125: 2 nodes
# Community 1126: 2 nodes
# Community 1127: 2 nodes
# Community 1128: 2 nodes
# Community 1130: 2 nodes
# Community 1132: 2 nodes
# Community 1134: 2 nodes
# Community 1135: 2 nodes
# Community 1137: 2 nodes
# Community 1138: 2 nodes
# Community 1143: 2 nodes
# Community 1144: 2 nodes
# Community 1146: 2 nodes
# Community 1147: 2 nodes
# Community 1148: 2 nodes
# Community 1149: 2 nodes
# Community 1150: 2 nodes
# Community 1151: 2 nodes
# Community 1153: 2 nodes
# Community 1154: 2 nodes
# Community 1156: 2 nodes
# Community 1157: 2 nodes
# Community 1158: 2 nodes
# Community 1160: 2 nodes
# Community 1161: 2 nodes
# Community 1162: 2 nodes
# Community 1163: 2 nodes
# Community 1164: 2 nodes
# Community 1165: 2 nodes
# Community 1167: 2 nodes
# Community 1168: 2 nodes
# Community 1169: 2 nodes
# Community 1171: 2 nodes
# Community 1172: 2 nodes
# Community 1174: 2 nodes
# Community 1175: 2 nodes
# Community 1176: 2 nodes
# Community 1177: 2 nodes
# Community 1179: 2 nodes
# Community 1180: 2 nodes
# Community 1181: 2 nodes
# Community 1182: 2 nodes
# Community 1184: 2 nodes
# Community 1188: 2 nodes
# Community 1189: 2 nodes
# Community 1190: 2 nodes
# Community 1191: 2 nodes
# Community 1193: 2 nodes
# Community 1194: 2 nodes
# Community 1196: 2 nodes
# Community 1198: 2 nodes
# Community 1200: 2 nodes
# Community 1206: 2 nodes
# Community 1208: 2 nodes
# Community 1209: 2 nodes
# Community 1210: 2 nodes
# Community 1212: 2 nodes
# Community 1214: 2 nodes
# Community 1216: 2 nodes
# Community 1217: 2 nodes
# Community 1219: 2 nodes
# Community 1220: 2 nodes
# Community 1221: 2 nodes
# Community 1222: 2 nodes
# Community 1223: 2 nodes
# Community 1227: 2 nodes
# Community 1228: 2 nodes
# Community 1229: 2 nodes
# Community 1230: 2 nodes
# Community 1231: 2 nodes
# Community 1232: 2 nodes
# Community 1233: 2 nodes
# Community 1236: 2 nodes
# Community 1237: 2 nodes
# Community 1238: 2 nodes
# Community 1240: 2 nodes
# Community 1244: 2 nodes
# Community 1248: 2 nodes
# Community 1250: 2 nodes
# Community 1252: 2 nodes
# Community 1253: 2 nodes
# Community 1255: 2 nodes
# Community 1256: 2 nodes
# Community 1257: 2 nodes
# Community 1259: 2 nodes
# Community 1261: 2 nodes
# Community 1262: 2 nodes
# Community 1263: 2 nodes
# Community 1264: 2 nodes
# Community 1267: 2 nodes
# Community 1270: 2 nodes
# Community 1272: 2 nodes
# Community 1273: 2 nodes
# Community 1274: 2 nodes
# Community 1275: 2 nodes
# Community 1278: 2 nodes
# Community 1279: 2 nodes
# Community 1280: 2 nodes
# Community 1281: 2 nodes
# Community 1283: 2 nodes
# Community 1284: 2 nodes
# Community 1285: 2 nodes
# Community 1286: 2 nodes
# Community 1287: 2 nodes
# Community 1289: 2 nodes
# Community 1290: 2 nodes
# Community 1291: 2 nodes
# Community 1292: 2 nodes
# Community 1295: 2 nodes
# Community 1297: 2 nodes
# Community 1298: 2 nodes
# Community 1299: 2 nodes
# Community 1301: 2 nodes
# Community 1302: 2 nodes
# Community 1305: 2 nodes
# Community 1306: 2 nodes
# Community 1308: 2 nodes
# Community 1309: 2 nodes
# Community 1310: 2 nodes
# Community 1311: 2 nodes
# Community 1314: 2 nodes
# Community 1316: 2 nodes
# Community 1318: 2 nodes
# Community 1319: 2 nodes
# Community 1320: 2 nodes
# Community 1321: 2 nodes
# Community 1322: 2 nodes
# Community 1323: 2 nodes
# Community 1324: 2 nodes
# Community 1326: 2 nodes
# Community 1328: 2 nodes
# Community 1329: 2 nodes
# Community 1330: 2 nodes
# Community 1331: 2 nodes
# Community 1333: 2 nodes
# Community 1337: 2 nodes
# Community 1338: 2 nodes
# Community 1342: 2 nodes
# Community 1343: 2 nodes
# Community 1344: 2 nodes
# Community 1345: 2 nodes
# Community 1346: 2 nodes
# Community 1347: 2 nodes
# Community 1348: 2 nodes
# Community 1349: 2 nodes
# Community 1351: 2 nodes
# Community 1353: 2 nodes
# Community 1354: 2 nodes
# Community 1355: 2 nodes
# Community 1361: 2 nodes
# Community 1362: 2 nodes
# Community 1365: 2 nodes
# Community 1367: 2 nodes
# Community 1368: 2 nodes
# Community 1371: 2 nodes
# Community 1373: 2 nodes
# Community 1374: 2 nodes
# Community 1375: 2 nodes
# Community 1377: 2 nodes
# Community 1379: 2 nodes
# Community 1381: 2 nodes
# Community 1385: 2 nodes
# Community 1386: 2 nodes
# Community 1387: 2 nodes
# Community 1389: 2 nodes
# Community 1390: 2 nodes
# Community 1391: 2 nodes
# Community 1393: 2 nodes
# Community 1394: 2 nodes
# Community 1395: 2 nodes
# Community 1396: 2 nodes
# Community 1397: 2 nodes
# Community 1398: 2 nodes
# Community 1399: 2 nodes
# Community 1401: 2 nodes
# Community 1402: 2 nodes
# Community 1403: 2 nodes
# Community 1404: 2 nodes
# Community 1405: 2 nodes
# Community 1407: 2 nodes
# Community 1408: 2 nodes
# Community 1409: 2 nodes
# Community 1410: 2 nodes
# Community 1411: 2 nodes
# Community 1412: 2 nodes
# Community 1414: 2 nodes
# Community 1415: 2 nodes
# Community 1416: 2 nodes
# Community 1418: 2 nodes
# Community 1419: 2 nodes
# Community 1420: 2 nodes
# Community 1423: 2 nodes
# Community 1424: 2 nodes
# Community 1425: 2 nodes
# Community 1426: 2 nodes
# Community 1427: 2 nodes
# Community 1428: 2 nodes
# Community 1430: 2 nodes
# Community 1434: 2 nodes
# Community 1435: 2 nodes
# Community 1436: 2 nodes
# Community 1437: 2 nodes
# Community 1438: 2 nodes
# Community 1439: 2 nodes
# Community 1441: 2 nodes
# Community 1442: 2 nodes
# Community 1443: 2 nodes
# Community 1444: 2 nodes
# Community 1445: 2 nodes
# Community 1447: 2 nodes
# Community 1448: 2 nodes
# Community 1449: 2 nodes
# Community 1451: 2 nodes
# Community 1452: 2 nodes
# Community 1453: 2 nodes
# Community 1456: 2 nodes
# Community 1460: 2 nodes
# Community 1461: 2 nodes
# Community 1463: 2 nodes
# Community 1464: 2 nodes
# Community 1465: 2 nodes
# Community 1466: 2 nodes
# Community 1467: 2 nodes
# Community 1469: 2 nodes
# Community 1470: 2 nodes
# Community 1472: 2 nodes
# Community 1473: 2 nodes
# Community 1474: 2 nodes
# Community 1475: 2 nodes
# Community 1476: 2 nodes
# Community 1477: 2 nodes
# Community 1479: 2 nodes
# Community 1480: 2 nodes
# Community 1481: 2 nodes
# Community 1482: 2 nodes
# Community 1483: 2 nodes
# Community 1484: 2 nodes
# Community 1485: 2 nodes
# Community 1488: 2 nodes
# Community 1490: 2 nodes
# Community 1492: 2 nodes
# Community 1493: 2 nodes
# Community 1494: 2 nodes
# Community 1495: 2 nodes
# Community 1497: 2 nodes
# Community 1498: 2 nodes
# Community 1499: 2 nodes
# Community 1500: 2 nodes
# Community 1501: 2 nodes
# Community 1502: 2 nodes
# Community 1503: 2 nodes
# Community 1504: 2 nodes
# Community 1506: 2 nodes
# Community 1507: 2 nodes
# Community 1508: 2 nodes
# Community 1509: 2 nodes
# Community 1510: 2 nodes
# Community 1511: 2 nodes
# Community 1513: 2 nodes
# Community 1514: 2 nodes
# Community 1515: 2 nodes
# Community 1516: 2 nodes
# Community 1517: 2 nodes
# Community 1518: 2 nodes
# Community 1519: 2 nodes
# Community 1521: 2 nodes
# Community 1522: 2 nodes
# Community 1523: 2 nodes
# Community 1525: 2 nodes
# Community 1526: 2 nodes
# Community 1527: 2 nodes
# Community 1528: 2 nodes
# Community 17: 2 nodes
# Community 84: 1 nodes
# Community 98: 1 nodes
# Community 102: 1 nodes
# Community 108: 1 nodes
# Community 110: 1 nodes
# Community 173: 1 nodes
# Community 232: 1 nodes
# Community 234: 1 nodes
# Community 291: 1 nodes
# Community 293: 1 nodes
# Community 301: 1 nodes
# Community 310: 1 nodes
# Community 332: 1 nodes
# Community 361: 1 nodes
# Community 370: 1 nodes
# Community 375: 1 nodes
# Community 391: 1 nodes
# Community 401: 1 nodes
# Community 410: 1 nodes
# Community 422: 1 nodes
# Community 463: 1 nodes
# Community 468: 1 nodes
# Community 486: 1 nodes
# Community 496: 1 nodes
# Community 514: 1 nodes
# Community 524: 1 nodes
# Community 543: 1 nodes
# Community 556: 1 nodes
# Community 562: 1 nodes
# Community 585: 1 nodes
# Community 589: 1 nodes
# Community 606: 1 nodes
# Community 608: 1 nodes
# Community 610: 1 nodes
# Community 613: 1 nodes
# Community 614: 1 nodes
# Community 621: 1 nodes
# Community 635: 1 nodes
# Community 637: 1 nodes
# Community 641: 1 nodes
# Community 645: 1 nodes
# Community 651: 1 nodes
# Community 654: 1 nodes
# Community 675: 1 nodes
# Community 683: 1 nodes
# Community 687: 1 nodes
# Community 712: 1 nodes
# Community 735: 1 nodes
# Community 746: 1 nodes
# Community 765: 1 nodes
# Community 768: 1 nodes
# Community 789: 1 nodes
# Community 791: 1 nodes
# Community 817: 1 nodes
# Community 833: 1 nodes
# Community 836: 1 nodes
# Community 853: 1 nodes
# Community 866: 1 nodes
# Community 881: 1 nodes
# Community 894: 1 nodes
# Community 897: 1 nodes
# Community 908: 1 nodes
# Community 917: 1 nodes
# Community 924: 1 nodes
# Community 929: 1 nodes
# Community 936: 1 nodes
# Community 957: 1 nodes
# Community 965: 1 nodes
# Community 969: 1 nodes
# Community 986: 1 nodes
# Community 1000: 1 nodes
# Community 1003: 1 nodes
# Community 1009: 1 nodes
# Community 1031: 1 nodes
# Community 1034: 1 nodes
# Community 1039: 1 nodes
# Community 1049: 1 nodes
# Community 1050: 1 nodes
# Community 1075: 1 nodes
# Community 1087: 1 nodes
# Community 1098: 1 nodes
# Community 1100: 1 nodes
# Community 1113: 1 nodes
# Community 1118: 1 nodes
# Community 1122: 1 nodes
# Community 1140: 1 nodes
# Community 1145: 1 nodes
# Community 1166: 1 nodes
# Community 1170: 1 nodes
# Community 1173: 1 nodes
# Community 1186: 1 nodes
# Community 1197: 1 nodes
# Community 1199: 1 nodes
# Community 1203: 1 nodes
# Community 1215: 1 nodes
# Community 1241: 1 nodes
# Community 1246: 1 nodes
# Community 1247: 1 nodes
# Community 1251: 1 nodes
# Community 1266: 1 nodes
# Community 1296: 1 nodes
# Community 1325: 1 nodes
# Community 1357: 1 nodes
# Community 1380: 1 nodes
# Community 1406: 1 nodes
# Community 1413: 1 nodes
# Community 1417: 1 nodes
# Community 1422: 1 nodes
# Community 1432: 1 nodes

# %%
def leader_rank(G2, damping=0.85, tol=1e-6, max_iter=100):
    # Add the ground node connected to all other nodes
    ground_node = 'ground'
    G = G2.copy()
    G.add_node(ground_node)
    for node in set(G.nodes()) - {ground_node}:
        G.add_edge(ground_node, node)

    # Create a mapping from node to index
    node_list = list(G.nodes())
    node_index = {node: i for i, node in enumerate(node_list)}
    n = len(node_list)
    
    # Initialize scores to 1 for all nodes
    scores = np.ones(n)
    
    # Create adjacency matrix
    row = []
    col = []
    data = []
    for node in G.nodes():
        neighbors = list(G.neighbors(node))
        if neighbors:
            for neighbor in neighbors:
                row.append(node_index[neighbor])
                col.append(node_index[node])
                data.append(1.0 / len(neighbors))
    
    adjacency_matrix = csr_matrix((data, (row, col)), shape=(n, n))
    
    # Power iteration: iterate until convergence
    for _ in range(max_iter):
        new_scores = adjacency_matrix.dot(scores)
        new_scores[node_index[ground_node]] = np.sum(scores)  # Special handling for the ground node
        if np.linalg.norm(new_scores - scores, 1) < tol:
            scores = new_scores
            break
        scores = new_scores
    
    # Remove the ground node score and normalize the scores
    ground_node_score = scores[node_index[ground_node]]
    total_score = np.sum(scores) - ground_node_score
    scores = (scores - ground_node_score / n) / total_score
    
    # Create the final scores dictionary
    final_scores = {node_list[i]: scores[i] for i in range(n) if node_list[i] != ground_node}
    
    return final_scores





def calculate_h_index(G):
    h_index = {}
    for node in G.nodes():
        degrees = [G.degree(neighbor) for neighbor in G.neighbors(node)]
        degrees.sort(reverse=True)
        h = 0
        for i, degree in enumerate(degrees):
            if degree >= i + 1:
                h = i + 1
            else:
                break
        h_index[node] = h
    return h_index

# %%
# Initialize an empty directed graph
# Load the .mtx file
wiki_path = '/Users/qing/Desktop/24s1/comp8880/project/code/data/wiki-Vote.txt'
G_wiki = read_directed_graph(wiki_path,4)
# Calculate number of nodes and edges in the graph
num_nodes = G_wiki.number_of_nodes()
num_edges = G_wiki.number_of_edges()

num_nodes, num_edges

centrality = nx.degree_centrality(G_wiki)
betweenness_manual = nx.betweenness_centrality(G_wiki)
closeness_manual = nx.closeness_centrality(G_wiki)
pagerank = nx.pagerank(G_wiki, alpha=0.85, personalization=None)
leaderRank = leader_rank(G_wiki)
hIndex = calculate_h_index(G_wiki)
kShell = nx.core_number(G_wiki)

sorted_centrality = sorted(centrality.items(), key=lambda item: item[1], reverse=True)
sorted_betweenness = sorted(betweenness_manual.items(), key=lambda item: item[1], reverse=True)
sorted_closeness = sorted(closeness_manual.items(), key=lambda item: item[1], reverse=True)
sorted_pagerank =  sorted(pagerank.items(), key=lambda item: item[1], reverse=True)
sorted_leaderRank =  sorted(leaderRank.items(), key=lambda item: item[1], reverse=True)
sorted_hIndex =  sorted(hIndex.items(), key=lambda item: item[1], reverse=True)
sorted_kShell=  sorted(kShell.items(), key=lambda item: item[1], reverse=True)


print(sorted_centrality[:3])
print(sorted_betweenness[:3])
print(sorted_closeness[:3])
print(sorted_pagerank[:3])
print(sorted_leaderRank[:3])
print(sorted_hIndex[:3])
print(sorted_kShell[:3])



# 假设 sorted_centrality, sorted_betweenness 等都是已经计算好并排序的元组列表
data_to_save = {
    "Centrality": sorted_centrality,
    "Betweenness": sorted_betweenness,
    "Closeness": sorted_closeness,
    "PageRank": sorted_pagerank,
    "LeaderRank": sorted_leaderRank,
    "HIndex": sorted_hIndex,
    "KShell": sorted_kShell
}

with open('saved/network_metrics_wiki.json', 'w') as f:
    json.dump(data_to_save, f, indent=4)
